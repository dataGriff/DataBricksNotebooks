# %% [markdown]
# First off make secure connection data bricks account to both raw and curated data lakes, we would only want this on through day ETLs for example

# %%
spark.conf.set("fs.azure.account.auth.type", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id", "{clientid}")
spark.conf.set("fs.azure.account.oauth2.client.secret", "{clientsecret}")
spark.conf.set("fs.azure.account.oauth2.client.endpoint", "https://login.microsoftonline.com/{tenantid}/oauth2/token")
spark.conf.set("fs.azure.createRemoteFileSystemDuringInitialization", "true")
dbutils.fs.ls("abfss://test@griffvnetlk2.dfs.core.windows.net/")
dbutils.fs.ls("abfss://test@griffvnetlk2curated.dfs.core.windows.net/")
spark.conf.set("fs.azure.createRemoteFileSystemDuringInitialization", "false")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Then read into data frame from raw data lake

# %%
pathraw = "abfss://test@griffvnetlk2.dfs.core.windows.net/TestUpload.csv"

dfraw = (spark
  .read
  .option("header", True)
  .csv(pathraw)
)

display(dfraw)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>char</th></tr></thead><tbody><tr><td>1</td><td> a</td></tr></tbody></table></div>

# %% [markdown]
# Write into curated data lake as parquet

# %%
pathcurated = "abfss://test@griffvnetlk2curated.dfs.core.windows.net/TestUpload.parquet"

dfraw.write.option("header", "true").parquet(pathcurated)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">Py4JJavaError</span>                             Traceback (most recent call last)
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">     62</span>         <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# ...

# %% [markdown]
# read from curated data lake into dataframe to prove moved and in different format

# %%
dfcurated = (spark
  .read
  .option("header", True)
  .parquet(pathcurated)
)

display(dfcurated)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>char</th></tr></thead><tbody><tr><td>1</td><td> a</td></tr></tbody></table></div>

# %% [markdown]
# place data into a databricks table example and can query like sql, see the structure under data on the left

# %%
# %sql 

DROP TABLE IF EXISTS test;

CREATE TABLE test USING parquet OPTIONS (path "abfss://test@griffvnetlk2curated.dfs.core.windows.net/TestUpload.parquet");

SELECT * FROM test;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>char</th></tr></thead><tbody><tr><td>1</td><td> a</td></tr></tbody></table></div>
